# %% [markdown]
# <a href="https://colab.research.google.com/github/tiagoflorin/DataScience1/blob/clase_6/Primera_entrega_DSI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Presentación del proyecto**

# %% [markdown]
# **Abstracto con Motivación y Audiencia**

# %% [markdown]
# **Contexto Comercial y Analítico**

# %% [markdown]
# **Preguntas/Hipótesis a Resolver mediante el Análisis de Datos**

# %% [markdown]
# **Objetivo**

# %% [markdown]
# # **Lectura de datos**

# %% [markdown]
# **Librerias necesarias para el analisis de datos**

# %% [markdown]
# **Configuración del entorno de Python en Google Colab**

# %% [markdown]
# **Lectura del dataset**

# %% [markdown]
# **Análisis inicial del dataset**

# %% [markdown]
# **Descripción de variables**

# %% [markdown]
# # **Data Wrangling - Limpieza y transformación de datos**

# %% [markdown]
# **Valores duplicados**

# %% [markdown]
# **Valores nulos**

# %% [markdown]
# **Tratamiento de valores outliers**

# %% [markdown]
# **Otras transformaciones, normalización, fechas**

# %% [markdown]
# # **Análisis Exploratorio de datos**

# %% [markdown]
# **Análisis univariado**

# %% [markdown]
# **Análisis bivariado**

# %% [markdown]
# **Análisis multivariado**

# %% [markdown]
# **Conclusiones del EDA**
