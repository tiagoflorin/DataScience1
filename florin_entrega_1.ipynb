# %% [markdown]
# <a href="https://colab.research.google.com/github/tiagoflorin/DataScience1/blob/clase_6/florin_entrega_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Abstract**
#
# El objetivo del proyecto es hacer un analisis para investigar sobre el consumo de musica por streaming en los ultimos años. El proyecto tiene como objetivo principal realizar un análisis exhaustivo de la música más escuchada en los últimos años, con el fin de identificar patrones y tendencias clave en los gustos musicales globales.

# %% [markdown]
# **Hipotesis**
#
# Hoy en dia la mayoría  de las personas escuchan música bailable.
# Se plantea que la música bailable, especialmente dentro de géneros como el reguetón, la música electrónica y el pop, ha experimentado un crecimiento significativo en popularidad durante los últimos años, impulsada por factores como la globalización de las plataformas de streaming, el aumento del consumo de música a través de redes sociales y el impacto de eventos masivos (como festivales y conciertos).

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
url_music_dataset = 'https://raw.githubusercontent.com/tiagoflorin/DataScience1/refs/heads/clase_6/ProyectoFinal_Florin.csv'

# %%
music_data = pd.DataFrame(music_data)

# %%
music_data = pd.read_csv(url_music_dataset, sep=';')

print(music_data.head())
# Out:
#   Energy  Tempo en  BPM Danceability Playlist_genre2 Valence  \
# 0    81%           93.0          68%       Afrobeats     76%
# 1    65%           93.0          74%       Afrobeats     75%
# 2    79%          113.0          75%       Afrobeats     90%
# 3    87%          118.0          77%       Afrobeats     93%
# 4    63%          101.0          50%       Afrobeats     65%
#
#            Track_artist  Track_popularity Playlist_name  \
# 0                  Tyla              78.0     Afro Hits
# 1  Wizkid, Brent Faiyaz              77.0  African Heat
# 2     Davido, YG Marley              76.0  African Heat
# 3                Wizkid              75.0     Afro Hits
# 4         Asake, Wizkid              72.0  African Heat
#
#                                Track_name Track_album_release_date  Mode  Key  \
# 0                            PUSH 2 START                 11/10/24   1.0  2.0
# 1  Piece of My Heart (feat. Brent Faiyaz)                 18/10/24   1.0  1.0
# ...

# %%
music_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1687 entries, 0 to 1686
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Energy                    1674 non-null   object
#  1   Tempo en  BPM             1674 non-null   float64
#  2   Danceability              1674 non-null   object
#  3   Playlist_genre2           1674 non-null   object
#  4   Valence                   1674 non-null   object
#  5   Track_artist              1674 non-null   object
#  6   Track_popularity          1674 non-null   float64
#  7   Playlist_name             1674 non-null   object
#  8   Track_name                1674 non-null   object
#  9   Track_album_release_date  1674 non-null   object
#  10  Mode                      1674 non-null   float64
#  11  Key                       1674 non-null   float64
#  12  Duration_minutes          1674 non-null   float64
# ...

# %%
plt.figure(figsize=(20, 8))
plt.hist(music_data.Track_popularity, bins=10, color='skyblue', edgecolor='black')

# Etiquetas y título
plt.title("Grafico de la Popularidad por Genero")
plt.xlabel("Generos")
plt.ylabel("Popularidad")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20, 8))
plt.hist(music_data.Playlist_genre2, bins=10, color='skyblue', edgecolor='black')

# Etiquetas y título
plt.title("Grafico de la Popularidad por Genero")
plt.xlabel("Generos")
plt.ylabel("Popularidad")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-28-1371394893.py in <cell line: 0>()
#       1 plt.figure(figsize=(20, 8))
# ----> 2 plt.hist(music_data.Playlist_genre2, bins=10, color='skyblue', edgecolor='black')
#       3
#       4 # Etiquetas y título
#       5 plt.title("Grafico de la Popularidad por Genero")
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     451                 "parameter will become keyword-only in %(removal)s.",
#     452                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453         return func(*args, **kwargs)
#     454
#     455     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# ...

# %%
music_data.info()

# %%
import seaborn as sns


sns.kdeplot(data=music_data, x=Playlist_genre2, hue=Track_popularity, fill=True)
plt.title("Distribución de edades de jugadores de fútbol")
plt.xlabel("Edad")
plt.ylabel("Cantidad de jugadores")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
